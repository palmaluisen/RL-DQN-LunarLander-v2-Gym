# %% [markdown]
# # Trabajo de módulo: Aprendizaje Reforzado
# ## Desarrollo de un modelo para solucionar el entorno 'LunarLander-v2'
# ### Por: Luis Palma

# %%
# Cargar librerias
import gym                      # entorno del juego
import numpy as np              # manejo de matrices
import torch                    # para el uso de Pytorch
import torch.nn as nn           # cargar nn 
import torch.optim as optim     # cargar optim de torch
import random                   # para la generación de numeros aleatorios
from collections import deque   # para el replay buffer
import time                     # para medir el tiempo de ejecución por episodio

# Configuración del entorno
env = gym.make('LunarLander-v2')                # crear entorno de juego
state_size = env.observation_space.shape[0]     # tamaño de los estados
action_size = env.action_space.n                # número de acciones disponibles en el entorno

# Hiperparámetros
n_episodes = 1000           # Aunque puede escogerse un número más grande, se fija 1000 para comparar con otros modelos y arquitecturas
batch_size = 64             # tamaño del lote (batch)
memory_size = 10000         # tamaño de la memoria
gamma = 0.99                # Factor de descuento
epsilon = 1.0               # Tasa de exploración inicial
epsilon_min = 0.05          # Tasa de exploración mínima
epsilon_decay = 0.996       # Tasa de decaimiento de la tasa de exploración
learning_rate = 0.001       # tasa de aprendizaje de la red

# Creación del modelo de red neuronal principal
class DQN(nn.Module):                               # Creamos la clase 'DQN' que se hereda de 'nn.Module' 
    def __init__(self, state_size, action_size):    # Declaración del método init de la clase y declaración de argumentos de la clase 
        super(DQN, self).__init__()                 # declaración de herencia 
        self.fc1 = nn.Linear(state_size, 256)       # Declaración de la capa de entrada de tamaño state_size=8, y salida de 256
        self.fc2 = nn.Linear(256, 256)              # Declaración de capa oculta de 256 neuronas de entrada y salida  
        self.fc3 = nn.Linear(256, action_size)      # Declaración de capa de 256 y de salida action_size = 4

    def forward(self, x):           # Declaración del método forward x serán los state convertidos a tensor
        x = torch.relu(self.fc1(x)) # aplica una función de activación reLU a la capa fc1
        x = torch.relu(self.fc2(x)) # aplica una función de activación reLU a la capa fc2
        x = self.fc3(x)             # pasa por la última capa sin aplicar una función de activación, porque se espera que sea una combinación lineal de su entrada y los pesos aprendidos
        return x                    # devuelve el resultado de la propagación de los datos por la red

model = DQN(state_size, action_size)                            # Crea una instancia del modelo de red 'DQN' con los argumentos state_size y action_size, este es el modelo principal
optimizer = optim.Adam(model.parameters(), lr=learning_rate)    # Se crea un optimizador Adam

# Creación del modelo de red neuronal objetivo
target_model = DQN(state_size, action_size)         # Con este modelo se harán las predicciones es equivalente al modelo principal
target_model.load_state_dict(model.state_dict())    # Inicializa los pesos del target_model con los del modelo principal

# Creación del replay buffer
memory = deque(maxlen=memory_size)                  # Instanciación del buffer en un objeto deque de tamaño memory_size

# Función de acción epsilon-greedy
def epsilon_greedy_action(state, epsilon):                      # Declaración de una función con argumentos state, epilon que dedicidirá si explorar o explotar el entorno
    if np.random.rand() <= epsilon:                             # si un número aleatorio es menor o igual que el epilon
        return env.action_space.sample()                        # Explora! (devuelve una acción aleatoria)
    else:                                                       # si no... Explota! 
        state = torch.from_numpy(state).float().unsqueeze(0)    # convertir el state de numpy a tensor y agrega una dimensión para utilizarse como entrada de la red neuronal
        with torch.no_grad():                                   # No actualizar gradientes 
            q_values = model(state)                             # Inferencia del modelo y obtener el q_value de cada acción
        return torch.argmax(q_values).item()                    # Devuelve la posición que tiene el máximo valor de acción

# Listas de evolución                                           # Crear listas vacias para guardar datos y rendimientos     
reward_per_episode = []                                         # recompensa por episodio
epsilon_evolution = []                                          # evolución del epsilon
actions_per_episode = []                                        # Acciones por episodio
time_per_episode = []                                           # tiempo en segundos por episodio

# Entrenamiento del agente
for episode in range(n_episodes):                            # Declaración del bucle con n_episodes episodios
    start_time = time.time()                                 # Declararación de hora inicial de inicio del bucle
    state = env.reset()                                      # reinicio del entorno al iniciar el bucle
    total_reward = 0                                         # Reinicio a cero del objeto total_reward
    done = False                                             # Reinicio a False la variable de condición de finalización del episodio
    act = 0                                                  # Reinicio a cero del número de acciones por episodio

    while not done:                                             # Inicio del Juego (Mientras no termine)
        # if episode % 50==0:                                   # Si el número de episodio es múltiplo de 50 
        #     env.render()                                      # Renderizar
        act += 1                                                # Sumar una acción 

        # Elegir acción
        action = epsilon_greedy_action(state, epsilon)              # Escoge una acción mediante la politica epsilon-greedy

        # Realizar acción y obtener siguiente estado, recompensa y estado de finalización
        next_state, reward, done, _ = env.step(action)              # Obtener la siguiente observación, recompensa y si finaliza 

        # Almacenar la transición en el replay buffer
        memory.append((state, action, reward, next_state, done))    # Guardar en memory: el estado, acción, recompensa, estado siguiente y finalización o no. 

        # Actualizar estado actual
        state = next_state                                          # Guardar como estado el siguiente estado 
        total_reward += reward                                      # sumar a total_reward la recompensa de la acción

        # Actualizar la red neuronal utilizando el replay buffer
        if len(memory) > batch_size:                                                # Comprobar si el tamaño de la memoria es mayor que el tamaño 'batch_size':
            batch = random.sample(memory, batch_size)                               # Guardar en el batch la cantidad de 'batch_size' datos aleatorios 
            states, actions, rewards, next_states, dones = zip(*batch)              # las transiciones se descomprinen en cinto listas:  'states', 'actions', 'rewards', 'next_states', 'dones'

            states = torch.tensor(states, dtype=torch.float32)                      # convertir a tensores
            actions = torch.tensor(actions)                                         # convertir a tensores
            rewards = torch.tensor(rewards, dtype=torch.float32)                    # convertir a tensores
            next_states = torch.tensor(next_states, dtype=torch.float32)            # convertir a tensores
            dones = torch.tensor(dones, dtype=torch.float32)                        # convertir a tensores

            current_q_values = model(states).gather(1, actions.unsqueeze(1))        # obtener los Q actuales del modelo de red neuronal para los estados y acciones del batch. 
            next_q_values = target_model(next_states).max(1)[0].detach()            # obtener los Q siguientes del modelo de red neuronal objetivo target_model y se pone el máximo valor de cada uno en un tensor
            target_q_values = rewards + gamma * next_q_values * (1 - dones)         # obtener los Q objetivo, se calculan la fórmula de actualización del algoritmo DQN: recompensas actuales, más el factor de descuento multiplicado por los valores Q siguientes, teniendo en cuenta si el episodio ha finalizado

            loss = nn.MSELoss()(current_q_values, target_q_values.unsqueeze(1))     # cálculo de la pérdida utilizando el MSE
            optimizer.zero_grad()                                                   # reinicio de gradientes de la red a cero
            loss.backward()                                                         # Retropropagación de la pérdida
            optimizer.step()                                                        # Actualización de los parámetros del modelo

        # Actualizar tasa de exploración
        if epsilon > epsilon_min:                                                   # Comprobar si epsilon es mayor que el epsilon_min
            epsilon *= epsilon_decay                                                # Multiplicar el epsilon por la tasa de decaimiento de la tasa de exploración

    # Actualizar el modelo objetivo al final de cada episodio
    if episode % 10 == 0:                                                           # Cada 10 episodios 
        target_model.load_state_dict(model.state_dict())                            # actualizar el target_model con los pesos del model 

    # Guardar registros de rendimiento del modelo
    end_time = time.time()  # Obtener el tiempo de finalización                     # Guardar la hora de finalización del bucle while
    execution_time = end_time - start_time                                          # diferencia de hora final menos hora iniical
    time_per_episode.append(round(execution_time,1))                                # Guardar el tiempo de ejecución en la lista time_per_episode
    reward_per_episode.append(total_reward)                                         # Guardar la Recompensa total en la lista reward_per_episode 
    actions_per_episode.append(act)                                                 # Guardar el número de acciones en la lista actions_per_episode
    epsilon_evolution.append(epsilon)                                               # Guardar el epsilon en la lista epsilon_evolution
    print("Episodio:", episode, "| Recompensa total:", total_reward, "| Acciones/episodio: ", act, "| Segundos/episodio: ", execution_time) # imprime la evolución

env.close()
# Out:
# Episodio: 0 | Recompensa total: -183.5401187642736 | Acciones/episodio:  135 | Segundos/episodio:  0.4280662536621094
# Episodio: 1 | Recompensa total: -294.8842529603147 | Acciones/episodio:  155 | Segundos/episodio:  0.548011064529419
# Episodio: 2 | Recompensa total: -241.96221467559556 | Acciones/episodio:  117 | Segundos/episodio:  0.3794589042663574
# Episodio: 3 | Recompensa total: -390.2785274320423 | Acciones/episodio:  251 | Segundos/episodio:  0.7977731227874756
# Episodio: 4 | Recompensa total: -101.56621976221773 | Acciones/episodio:  139 | Segundos/episodio:  0.4376680850982666
# Episodio: 5 | Recompensa total: -260.8952782753427 | Acciones/episodio:  246 | Segundos/episodio:  0.8057730197906494
# Episodio: 6 | Recompensa total: -310.1808192061429 | Acciones/episodio:  110 | Segundos/episodio:  0.353701114654541
# Episodio: 7 | Recompensa total: -142.1248078736399 | Acciones/episodio:  200 | Segundos/episodio:  0.6286358833312988
# Episodio: 8 | Recompensa total: -238.04420855193823 | Acciones/episodio:  229 | Segundos/episodio:  0.6960058212280273
# Episodio: 9 | Recompensa total: -261.89072114214525 | Acciones/episodio:  326 | Segundos/episodio:  1.0861811637878418
# Episodio: 10 | Recompensa total: -161.4111211690808 | Acciones/episodio:  302 | Segundos/episodio:  1.0718531608581543
# Episodio: 11 | Recompensa total: -247.93045972191047 | Acciones/episodio:  253 | Segundos/episodio:  0.8588302135467529
# Episodio: 12 | Recompensa total: -290.10592370377697 | Acciones/episodio:  190 | Segundos/episodio:  0.6050629615783691
# Episodio: 13 | Recompensa total: -278.0824286156777 | Acciones/episodio:  138 | Segundos/episodio:  0.4392130374908447
# Episodio: 14 | Recompensa total: -121.3117924175467 | Acciones/episodio:  286 | Segundos/episodio:  0.9642848968505859
# Episodio: 15 | Recompensa total: -248.7286812654054 | Acciones/episodio:  162 | Segundos/episodio:  0.5095958709716797
# Episodio: 16 | Recompensa total: -229.8530283445981 | Acciones/episodio:  277 | Segundos/episodio:  0.9430439472198486
# Episodio: 17 | Recompensa total: -260.20813739115556 | Acciones/episodio:  247 | Segundos/episodio:  0.7859740257263184
# Episodio: 18 | Recompensa total: -230.5504709129287 | Acciones/episodio:  367 | Segundos/episodio:  1.436702013015747
# Episodio: 19 | Recompensa total: -196.0316907389015 | Acciones/episodio:  266 | Segundos/episodio:  0.8876159191131592
# Episodio: 20 | Recompensa total: -302.8049503598085 | Acciones/episodio:  425 | Segundos/episodio:  1.5803518295288086
# Episodio: 21 | Recompensa total: 3.071488015880334 | Acciones/episodio:  279 | Segundos/episodio:  1.0148258209228516
# Episodio: 22 | Recompensa total: -46.12079665809539 | Acciones/episodio:  193 | Segundos/episodio:  0.6785411834716797
# Episodio: 23 | Recompensa total: -169.50240983788063 | Acciones/episodio:  320 | Segundos/episodio:  1.1449131965637207
# Episodio: 24 | Recompensa total: -67.83841007333513 | Acciones/episodio:  399 | Segundos/episodio:  1.5797100067138672
# Episodio: 25 | Recompensa total: -318.31225079717876 | Acciones/episodio:  347 | Segundos/episodio:  1.1723289489746094
# Episodio: 26 | Recompensa total: -257.8545742495378 | Acciones/episodio:  308 | Segundos/episodio:  1.107820987701416
# Episodio: 27 | Recompensa total: -50.46930824197469 | Acciones/episodio:  396 | Segundos/episodio:  1.395596981048584
# Episodio: 28 | Recompensa total: -200.2667473740043 | Acciones/episodio:  181 | Segundos/episodio:  0.5896000862121582
# Episodio: 29 | Recompensa total: -47.96773440273948 | Acciones/episodio:  272 | Segundos/episodio:  0.9376220703125
# Episodio: 30 | Recompensa total: -34.481851776739234 | Acciones/episodio:  251 | Segundos/episodio:  0.8642189502716064
# Episodio: 31 | Recompensa total: -244.2223300766519 | Acciones/episodio:  356 | Segundos/episodio:  1.2534661293029785
# Episodio: 32 | Recompensa total: -69.78331876611642 | Acciones/episodio:  341 | Segundos/episodio:  1.161834955215454
# Episodio: 33 | Recompensa total: -206.47431483358446 | Acciones/episodio:  272 | Segundos/episodio:  0.9111659526824951
# Episodio: 34 | Recompensa total: -386.3121136935936 | Acciones/episodio:  425 | Segundos/episodio:  1.500525951385498
# Episodio: 35 | Recompensa total: -61.78743721652849 | Acciones/episodio:  290 | Segundos/episodio:  1.1320528984069824
# Episodio: 36 | Recompensa total: -65.96920266884743 | Acciones/episodio:  289 | Segundos/episodio:  1.0354433059692383
# Episodio: 37 | Recompensa total: -240.98373700251605 | Acciones/episodio:  508 | Segundos/episodio:  1.850661039352417
# Episodio: 38 | Recompensa total: -247.29479814176653 | Acciones/episodio:  415 | Segundos/episodio:  1.451585054397583
# Episodio: 39 | Recompensa total: -256.37601020995214 | Acciones/episodio:  435 | Segundos/episodio:  1.6078639030456543
# Episodio: 40 | Recompensa total: -262.0402331132009 | Acciones/episodio:  338 | Segundos/episodio:  1.2005338668823242
# Episodio: 41 | Recompensa total: -191.35252720725478 | Acciones/episodio:  286 | Segundos/episodio:  0.9535701274871826
# Episodio: 42 | Recompensa total: -41.22254337813626 | Acciones/episodio:  305 | Segundos/episodio:  1.023108959197998
# Episodio: 43 | Recompensa total: -25.583838895637783 | Acciones/episodio:  312 | Segundos/episodio:  1.0440998077392578
# Episodio: 44 | Recompensa total: -227.7837231647015 | Acciones/episodio:  397 | Segundos/episodio:  1.320363998413086
# Episodio: 45 | Recompensa total: -30.9719059601847 | Acciones/episodio:  329 | Segundos/episodio:  1.1033241748809814
# Episodio: 46 | Recompensa total: 238.22403919453816 | Acciones/episodio:  432 | Segundos/episodio:  1.5889739990234375
# Episodio: 47 | Recompensa total: -29.26845724139831 | Acciones/episodio:  347 | Segundos/episodio:  1.2735099792480469
# Episodio: 48 | Recompensa total: 260.04665277150804 | Acciones/episodio:  354 | Segundos/episodio:  1.3220758438110352
# Episodio: 49 | Recompensa total: -36.49849873930397 | Acciones/episodio:  391 | Segundos/episodio:  1.484462022781372
# Episodio: 50 | Recompensa total: -28.384463380163183 | Acciones/episodio:  246 | Segundos/episodio:  0.9343392848968506
# Episodio: 51 | Recompensa total: 169.19873704741366 | Acciones/episodio:  638 | Segundos/episodio:  2.591754913330078
# Episodio: 52 | Recompensa total: -270.9497279943537 | Acciones/episodio:  822 | Segundos/episodio:  3.043558120727539
# Episodio: 53 | Recompensa total: -104.70419002255177 | Acciones/episodio:  877 | Segundos/episodio:  4.0248939990997314
# Episodio: 54 | Recompensa total: -130.34541837888767 | Acciones/episodio:  801 | Segundos/episodio:  3.8584442138671875
# Episodio: 55 | Recompensa total: -107.63991344386382 | Acciones/episodio:  854 | Segundos/episodio:  3.9656457901000977
# Episodio: 56 | Recompensa total: -46.56094774521702 | Acciones/episodio:  426 | Segundos/episodio:  1.4521679878234863
# Episodio: 57 | Recompensa total: -140.00942130318222 | Acciones/episodio:  839 | Segundos/episodio:  3.4937169551849365
# Episodio: 58 | Recompensa total: -25.439433219069258 | Acciones/episodio:  373 | Segundos/episodio:  1.4202101230621338
# Episodio: 59 | Recompensa total: -92.69008968891956 | Acciones/episodio:  416 | Segundos/episodio:  1.515167236328125
# Episodio: 60 | Recompensa total: -61.38603383427221 | Acciones/episodio:  556 | Segundos/episodio:  2.053270101547241
# Episodio: 61 | Recompensa total: 126.65094851584206 | Acciones/episodio:  807 | Segundos/episodio:  3.407797336578369
# Episodio: 62 | Recompensa total: -264.6679048699067 | Acciones/episodio:  318 | Segundos/episodio:  1.039776086807251
# Episodio: 63 | Recompensa total: -60.83790432392405 | Acciones/episodio:  109 | Segundos/episodio:  0.37991881370544434
# Episodio: 64 | Recompensa total: 118.95016760022062 | Acciones/episodio:  927 | Segundos/episodio:  3.6766631603240967
# Episodio: 65 | Recompensa total: -128.68526010298842 | Acciones/episodio:  1000 | Segundos/episodio:  3.5505452156066895
# Episodio: 66 | Recompensa total: 109.05955277880899 | Acciones/episodio:  782 | Segundos/episodio:  2.9646871089935303
# Episodio: 67 | Recompensa total: -191.43508310895044 | Acciones/episodio:  288 | Segundos/episodio:  1.0753908157348633
# Episodio: 68 | Recompensa total: -147.05680243587713 | Acciones/episodio:  826 | Segundos/episodio:  3.518624782562256
# Episodio: 69 | Recompensa total: 0.7401422654270675 | Acciones/episodio:  327 | Segundos/episodio:  1.0877668857574463
# Episodio: 70 | Recompensa total: 6.97309707421816 | Acciones/episodio:  330 | Segundos/episodio:  1.131725788116455
# Episodio: 71 | Recompensa total: -118.77179772689732 | Acciones/episodio:  1000 | Segundos/episodio:  4.032119989395142
# Episodio: 72 | Recompensa total: 118.41529101539459 | Acciones/episodio:  642 | Segundos/episodio:  2.7014970779418945
# Episodio: 73 | Recompensa total: -139.51171282234446 | Acciones/episodio:  1000 | Segundos/episodio:  5.1924920082092285
# Episodio: 74 | Recompensa total: 42.89074139443131 | Acciones/episodio:  1000 | Segundos/episodio:  4.063875913619995
# Episodio: 75 | Recompensa total: -89.96573704311452 | Acciones/episodio:  1000 | Segundos/episodio:  3.7155420780181885
# Episodio: 76 | Recompensa total: -153.22742303308803 | Acciones/episodio:  1000 | Segundos/episodio:  4.745124816894531
# Episodio: 77 | Recompensa total: -171.2561204042358 | Acciones/episodio:  254 | Segundos/episodio:  0.8375239372253418
# Episodio: 78 | Recompensa total: -135.8421486947753 | Acciones/episodio:  1000 | Segundos/episodio:  4.660390853881836
# Episodio: 79 | Recompensa total: -143.5621211276781 | Acciones/episodio:  1000 | Segundos/episodio:  4.9436070919036865
# Episodio: 80 | Recompensa total: -154.76815732038855 | Acciones/episodio:  1000 | Segundos/episodio:  5.159191131591797
# Episodio: 81 | Recompensa total: -93.55238412386281 | Acciones/episodio:  1000 | Segundos/episodio:  4.781025171279907
# Episodio: 82 | Recompensa total: -19.261304693997836 | Acciones/episodio:  1000 | Segundos/episodio:  4.417634010314941
# Episodio: 83 | Recompensa total: -79.19809431629503 | Acciones/episodio:  1000 | Segundos/episodio:  3.661478281021118
# Episodio: 84 | Recompensa total: -65.67952227096107 | Acciones/episodio:  1000 | Segundos/episodio:  3.9216089248657227
# Episodio: 85 | Recompensa total: -293.167925316283 | Acciones/episodio:  746 | Segundos/episodio:  2.8512539863586426
# Episodio: 86 | Recompensa total: -130.96636010885646 | Acciones/episodio:  1000 | Segundos/episodio:  4.227953910827637
# Episodio: 87 | Recompensa total: -107.5835043460555 | Acciones/episodio:  1000 | Segundos/episodio:  5.589796781539917
# Episodio: 88 | Recompensa total: -109.86883744260936 | Acciones/episodio:  1000 | Segundos/episodio:  4.623095750808716
# Episodio: 89 | Recompensa total: -130.3462245727711 | Acciones/episodio:  1000 | Segundos/episodio:  4.683051109313965
# Episodio: 90 | Recompensa total: -131.8902829998404 | Acciones/episodio:  1000 | Segundos/episodio:  4.182563781738281
# Episodio: 91 | Recompensa total: -105.44984554476684 | Acciones/episodio:  1000 | Segundos/episodio:  3.7465341091156006
# Episodio: 92 | Recompensa total: -98.65855025004618 | Acciones/episodio:  1000 | Segundos/episodio:  4.005345106124878
# Episodio: 93 | Recompensa total: -124.71436350528825 | Acciones/episodio:  73 | Segundos/episodio:  0.2167670726776123
# Episodio: 94 | Recompensa total: -90.8637540551188 | Acciones/episodio:  1000 | Segundos/episodio:  4.270799875259399
# Episodio: 95 | Recompensa total: -136.38001479348583 | Acciones/episodio:  1000 | Segundos/episodio:  4.07996392250061
# Episodio: 96 | Recompensa total: -131.9691479706188 | Acciones/episodio:  1000 | Segundos/episodio:  4.486386775970459
# Episodio: 97 | Recompensa total: -79.7556452592341 | Acciones/episodio:  1000 | Segundos/episodio:  4.128313064575195
# Episodio: 98 | Recompensa total: -96.1293002108693 | Acciones/episodio:  1000 | Segundos/episodio:  4.9379260540008545
# Episodio: 99 | Recompensa total: -117.99732973402926 | Acciones/episodio:  1000 | Segundos/episodio:  3.6742217540740967
# Episodio: 100 | Recompensa total: -98.7840538450039 | Acciones/episodio:  1000 | Segundos/episodio:  4.045428991317749
# Episodio: 101 | Recompensa total: -66.9127363986004 | Acciones/episodio:  1000 | Segundos/episodio:  4.091130018234253
# Episodio: 102 | Recompensa total: -90.3511775189459 | Acciones/episodio:  1000 | Segundos/episodio:  4.304383993148804
# Episodio: 103 | Recompensa total: -94.73802808821948 | Acciones/episodio:  1000 | Segundos/episodio:  4.446008205413818
# Episodio: 104 | Recompensa total: -56.70752970699489 | Acciones/episodio:  1000 | Segundos/episodio:  4.183538913726807
# Episodio: 105 | Recompensa total: -83.31498605824038 | Acciones/episodio:  1000 | Segundos/episodio:  4.610038995742798
# Episodio: 106 | Recompensa total: -80.54771738260303 | Acciones/episodio:  172 | Segundos/episodio:  0.5642111301422119
# Episodio: 107 | Recompensa total: -82.94820090859734 | Acciones/episodio:  1000 | Segundos/episodio:  4.262009143829346
# Episodio: 108 | Recompensa total: -87.86424953511718 | Acciones/episodio:  1000 | Segundos/episodio:  3.776817798614502
# Episodio: 109 | Recompensa total: -52.23889861232043 | Acciones/episodio:  1000 | Segundos/episodio:  4.268292665481567
# Episodio: 110 | Recompensa total: -65.74786744749096 | Acciones/episodio:  1000 | Segundos/episodio:  4.687582015991211
# Episodio: 111 | Recompensa total: -107.33945862300499 | Acciones/episodio:  203 | Segundos/episodio:  0.6562368869781494
# Episodio: 112 | Recompensa total: -118.33788154662594 | Acciones/episodio:  181 | Segundos/episodio:  0.5729241371154785
# Episodio: 113 | Recompensa total: -56.68022295401166 | Acciones/episodio:  1000 | Segundos/episodio:  4.479208946228027
# Episodio: 114 | Recompensa total: -90.2585368781923 | Acciones/episodio:  1000 | Segundos/episodio:  3.8023600578308105
# Episodio: 115 | Recompensa total: -58.589148494898254 | Acciones/episodio:  1000 | Segundos/episodio:  4.186774015426636
# Episodio: 116 | Recompensa total: -147.69958631890626 | Acciones/episodio:  379 | Segundos/episodio:  1.2533388137817383
# Episodio: 117 | Recompensa total: -100.00196198808827 | Acciones/episodio:  1000 | Segundos/episodio:  4.336699962615967
# Episodio: 118 | Recompensa total: -69.49531265444068 | Acciones/episodio:  1000 | Segundos/episodio:  3.8799798488616943
# Episodio: 119 | Recompensa total: -80.534429091631 | Acciones/episodio:  1000 | Segundos/episodio:  3.9450430870056152
# Episodio: 120 | Recompensa total: -69.02575901279081 | Acciones/episodio:  1000 | Segundos/episodio:  3.9371700286865234
# Episodio: 121 | Recompensa total: -205.99046708452525 | Acciones/episodio:  195 | Segundos/episodio:  0.6265668869018555
# Episodio: 122 | Recompensa total: -45.00277999183266 | Acciones/episodio:  1000 | Segundos/episodio:  3.7768571376800537
# Episodio: 123 | Recompensa total: -65.44069268961381 | Acciones/episodio:  1000 | Segundos/episodio:  3.6509666442871094
# Episodio: 124 | Recompensa total: -226.1434237028417 | Acciones/episodio:  174 | Segundos/episodio:  0.5606627464294434
# Episodio: 125 | Recompensa total: -88.55574242765852 | Acciones/episodio:  1000 | Segundos/episodio:  3.7754008769989014
# Episodio: 126 | Recompensa total: -110.23035696983678 | Acciones/episodio:  317 | Segundos/episodio:  1.0658531188964844
# Episodio: 127 | Recompensa total: -157.31110913684623 | Acciones/episodio:  283 | Segundos/episodio:  0.9404337406158447
# Episodio: 128 | Recompensa total: -107.48569062750467 | Acciones/episodio:  274 | Segundos/episodio:  0.8772499561309814
# Episodio: 129 | Recompensa total: -79.30706688093504 | Acciones/episodio:  1000 | Segundos/episodio:  3.65667986869812
# Episodio: 130 | Recompensa total: -109.81884317275856 | Acciones/episodio:  172 | Segundos/episodio:  0.5470919609069824
# Episodio: 131 | Recompensa total: -153.18633277032325 | Acciones/episodio:  585 | Segundos/episodio:  1.9771671295166016
# Episodio: 132 | Recompensa total: -100.62269973290071 | Acciones/episodio:  1000 | Segundos/episodio:  4.929255962371826
# Episodio: 133 | Recompensa total: -53.826660300316526 | Acciones/episodio:  1000 | Segundos/episodio:  4.0771708488464355
# Episodio: 134 | Recompensa total: -301.53389573069603 | Acciones/episodio:  165 | Segundos/episodio:  0.5382449626922607
# Episodio: 135 | Recompensa total: -102.18321718106357 | Acciones/episodio:  129 | Segundos/episodio:  0.4086761474609375
# Episodio: 136 | Recompensa total: -82.36149196192204 | Acciones/episodio:  1000 | Segundos/episodio:  4.099147081375122
# Episodio: 137 | Recompensa total: -91.58704814344472 | Acciones/episodio:  358 | Segundos/episodio:  1.180156946182251
# Episodio: 138 | Recompensa total: -80.44928924598749 | Acciones/episodio:  1000 | Segundos/episodio:  3.6732430458068848
# Episodio: 139 | Recompensa total: -187.64913541227352 | Acciones/episodio:  809 | Segundos/episodio:  3.732793092727661
# Episodio: 140 | Recompensa total: -149.7641285366274 | Acciones/episodio:  239 | Segundos/episodio:  0.7657809257507324
# Episodio: 141 | Recompensa total: -106.4128669523925 | Acciones/episodio:  232 | Segundos/episodio:  0.7266371250152588
# Episodio: 142 | Recompensa total: -161.9136736867166 | Acciones/episodio:  487 | Segundos/episodio:  1.6381421089172363
# Episodio: 143 | Recompensa total: -54.294613978636896 | Acciones/episodio:  224 | Segundos/episodio:  0.6997449398040771
# Episodio: 144 | Recompensa total: -85.04807533134296 | Acciones/episodio:  376 | Segundos/episodio:  1.2210109233856201
# Episodio: 145 | Recompensa total: -39.24681315176132 | Acciones/episodio:  1000 | Segundos/episodio:  3.8923048973083496
# Episodio: 146 | Recompensa total: -73.96008079999996 | Acciones/episodio:  1000 | Segundos/episodio:  4.386990070343018
# Episodio: 147 | Recompensa total: -94.84217582699898 | Acciones/episodio:  241 | Segundos/episodio:  0.8480942249298096
# Episodio: 148 | Recompensa total: -85.4440942416177 | Acciones/episodio:  1000 | Segundos/episodio:  4.141838073730469
# Episodio: 149 | Recompensa total: -88.55651446348215 | Acciones/episodio:  1000 | Segundos/episodio:  4.796360015869141
# Episodio: 150 | Recompensa total: -93.7080342272874 | Acciones/episodio:  1000 | Segundos/episodio:  3.8001410961151123
# Episodio: 151 | Recompensa total: -66.62525950220805 | Acciones/episodio:  194 | Segundos/episodio:  0.6075270175933838
# Episodio: 152 | Recompensa total: -85.52963585653879 | Acciones/episodio:  205 | Segundos/episodio:  0.6533310413360596
# Episodio: 153 | Recompensa total: -153.9197533954224 | Acciones/episodio:  428 | Segundos/episodio:  1.4553260803222656
# Episodio: 154 | Recompensa total: -118.12718013540565 | Acciones/episodio:  178 | Segundos/episodio:  0.5743496417999268
# Episodio: 155 | Recompensa total: -98.87012363432144 | Acciones/episodio:  343 | Segundos/episodio:  1.1320617198944092
# Episodio: 156 | Recompensa total: -84.66572022669034 | Acciones/episodio:  254 | Segundos/episodio:  0.822613000869751
# Episodio: 157 | Recompensa total: -65.40079905747277 | Acciones/episodio:  1000 | Segundos/episodio:  3.5096840858459473
# Episodio: 158 | Recompensa total: -72.40843470586428 | Acciones/episodio:  205 | Segundos/episodio:  0.6379818916320801
# Episodio: 159 | Recompensa total: -123.87640143509361 | Acciones/episodio:  241 | Segundos/episodio:  0.7344918251037598
# Episodio: 160 | Recompensa total: -197.2571650819204 | Acciones/episodio:  686 | Segundos/episodio:  2.7562339305877686
# Episodio: 161 | Recompensa total: -115.664010170639 | Acciones/episodio:  261 | Segundos/episodio:  0.8404421806335449
# Episodio: 162 | Recompensa total: -114.29731232470674 | Acciones/episodio:  1000 | Segundos/episodio:  4.686575174331665
# Episodio: 163 | Recompensa total: -86.82617044342584 | Acciones/episodio:  130 | Segundos/episodio:  0.3900461196899414
# Episodio: 164 | Recompensa total: -84.43069808369418 | Acciones/episodio:  1000 | Segundos/episodio:  4.781286001205444
# Episodio: 165 | Recompensa total: -95.26448863385653 | Acciones/episodio:  238 | Segundos/episodio:  0.726668119430542
# Episodio: 166 | Recompensa total: -388.9500805973644 | Acciones/episodio:  870 | Segundos/episodio:  3.624279022216797
# Episodio: 167 | Recompensa total: -71.06235503433552 | Acciones/episodio:  1000 | Segundos/episodio:  4.206809997558594
# Episodio: 168 | Recompensa total: -171.10366776961905 | Acciones/episodio:  125 | Segundos/episodio:  0.3872499465942383
# Episodio: 169 | Recompensa total: -59.434720463459854 | Acciones/episodio:  1000 | Segundos/episodio:  3.647196054458618
# Episodio: 170 | Recompensa total: -63.46506657637227 | Acciones/episodio:  1000 | Segundos/episodio:  4.689050912857056
# Episodio: 171 | Recompensa total: -39.14938684487805 | Acciones/episodio:  1000 | Segundos/episodio:  4.222990989685059
# Episodio: 172 | Recompensa total: -85.17870266484466 | Acciones/episodio:  1000 | Segundos/episodio:  4.2861011028289795
# Episodio: 173 | Recompensa total: -7.972841797687053 | Acciones/episodio:  196 | Segundos/episodio:  0.6211559772491455
# Episodio: 174 | Recompensa total: -87.50345138812237 | Acciones/episodio:  1000 | Segundos/episodio:  4.819161891937256
# Episodio: 175 | Recompensa total: -87.31831713288192 | Acciones/episodio:  1000 | Segundos/episodio:  3.4781911373138428
# Episodio: 176 | Recompensa total: -58.608602890817636 | Acciones/episodio:  1000 | Segundos/episodio:  3.794416904449463
# Episodio: 177 | Recompensa total: -80.38778060867723 | Acciones/episodio:  1000 | Segundos/episodio:  3.772365093231201
# Episodio: 178 | Recompensa total: -57.16458054168101 | Acciones/episodio:  1000 | Segundos/episodio:  3.8832809925079346
# Episodio: 179 | Recompensa total: -13.848941335553658 | Acciones/episodio:  1000 | Segundos/episodio:  4.733293771743774
# Episodio: 180 | Recompensa total: -39.185077556760156 | Acciones/episodio:  1000 | Segundos/episodio:  4.040143728256226
# Episodio: 181 | Recompensa total: -56.17848893392589 | Acciones/episodio:  1000 | Segundos/episodio:  4.7045371532440186
# Episodio: 182 | Recompensa total: -1.9817846725119823 | Acciones/episodio:  1000 | Segundos/episodio:  4.214296817779541
# Episodio: 183 | Recompensa total: -71.55546293439366 | Acciones/episodio:  1000 | Segundos/episodio:  4.666323900222778
# Episodio: 184 | Recompensa total: -19.8723041537324 | Acciones/episodio:  74 | Segundos/episodio:  0.22391414642333984
# Episodio: 185 | Recompensa total: -142.15544500450983 | Acciones/episodio:  819 | Segundos/episodio:  3.4108128547668457
# Episodio: 186 | Recompensa total: -146.1224453146525 | Acciones/episodio:  911 | Segundos/episodio:  4.010181188583374
# Episodio: 187 | Recompensa total: -34.86111155290825 | Acciones/episodio:  1000 | Segundos/episodio:  3.724639892578125
# Episodio: 188 | Recompensa total: -136.2567287560089 | Acciones/episodio:  772 | Segundos/episodio:  3.1021671295166016
# Episodio: 189 | Recompensa total: -107.80452239745223 | Acciones/episodio:  259 | Segundos/episodio:  0.8191618919372559
# Episodio: 190 | Recompensa total: 144.2625728409302 | Acciones/episodio:  775 | Segundos/episodio:  3.246509075164795
# Episodio: 191 | Recompensa total: -151.2439021243046 | Acciones/episodio:  89 | Segundos/episodio:  0.26361608505249023
# Episodio: 192 | Recompensa total: -120.8033742084308 | Acciones/episodio:  274 | Segundos/episodio:  0.8617432117462158
# Episodio: 193 | Recompensa total: -2.046323591033797 | Acciones/episodio:  85 | Segundos/episodio:  0.26656413078308105
# Episodio: 194 | Recompensa total: -30.056092236518516 | Acciones/episodio:  1000 | Segundos/episodio:  3.994727373123169
# Episodio: 195 | Recompensa total: -44.33757389267562 | Acciones/episodio:  1000 | Segundos/episodio:  5.086683750152588
# Episodio: 196 | Recompensa total: -74.2283958882383 | Acciones/episodio:  1000 | Segundos/episodio:  3.525365114212036
# Episodio: 197 | Recompensa total: -37.24826762531559 | Acciones/episodio:  144 | Segundos/episodio:  0.440540075302124
# Episodio: 198 | Recompensa total: -12.606296751770788 | Acciones/episodio:  1000 | Segundos/episodio:  3.904813051223755
# Episodio: 199 | Recompensa total: -2.1445623715149082 | Acciones/episodio:  135 | Segundos/episodio:  0.42718982696533203
# Episodio: 200 | Recompensa total: -91.75261092213034 | Acciones/episodio:  1000 | Segundos/episodio:  3.7916259765625
# Episodio: 201 | Recompensa total: -43.68374753680337 | Acciones/episodio:  85 | Segundos/episodio:  0.26137399673461914
# Episodio: 202 | Recompensa total: -122.21344220399469 | Acciones/episodio:  270 | Segundos/episodio:  0.8498733043670654
# Episodio: 203 | Recompensa total: -101.61071909678851 | Acciones/episodio:  106 | Segundos/episodio:  0.32639503479003906
# Episodio: 204 | Recompensa total: -10.251606637498103 | Acciones/episodio:  1000 | Segundos/episodio:  5.198132276535034
# Episodio: 205 | Recompensa total: -88.35522223931231 | Acciones/episodio:  133 | Segundos/episodio:  0.45627689361572266
# Episodio: 206 | Recompensa total: -140.54202659654706 | Acciones/episodio:  269 | Segundos/episodio:  0.8981790542602539
# Episodio: 207 | Recompensa total: -22.749291034343596 | Acciones/episodio:  1000 | Segundos/episodio:  4.433578968048096
# Episodio: 208 | Recompensa total: -58.717501854058284 | Acciones/episodio:  319 | Segundos/episodio:  1.1199848651885986
# Episodio: 209 | Recompensa total: -188.92590431253063 | Acciones/episodio:  147 | Segundos/episodio:  0.6088800430297852
# Episodio: 210 | Recompensa total: -145.90094814470308 | Acciones/episodio:  355 | Segundos/episodio:  1.9823589324951172
# Episodio: 211 | Recompensa total: -68.73710988172644 | Acciones/episodio:  1000 | Segundos/episodio:  4.356762170791626
# Episodio: 212 | Recompensa total: 5.933400118715567 | Acciones/episodio:  1000 | Segundos/episodio:  3.7516050338745117
# Episodio: 213 | Recompensa total: 47.54689879541931 | Acciones/episodio:  1000 | Segundos/episodio:  3.9283671379089355
# Episodio: 214 | Recompensa total: -148.55821936048602 | Acciones/episodio:  952 | Segundos/episodio:  5.12591290473938
# Episodio: 215 | Recompensa total: -234.26351082985317 | Acciones/episodio:  356 | Segundos/episodio:  1.4009971618652344
# Episodio: 216 | Recompensa total: -325.6126020612114 | Acciones/episodio:  291 | Segundos/episodio:  1.2886369228363037
# Episodio: 217 | Recompensa total: -337.89972136368044 | Acciones/episodio:  811 | Segundos/episodio:  4.017357110977173
# Episodio: 218 | Recompensa total: -280.313029866925 | Acciones/episodio:  191 | Segundos/episodio:  0.7285847663879395
# Episodio: 219 | Recompensa total: -64.78826605968497 | Acciones/episodio:  1000 | Segundos/episodio:  5.176439046859741
# Episodio: 220 | Recompensa total: -112.69421357130128 | Acciones/episodio:  610 | Segundos/episodio:  2.523836851119995
# Episodio: 221 | Recompensa total: 92.10489914526757 | Acciones/episodio:  998 | Segundos/episodio:  5.617763042449951
# Episodio: 222 | Recompensa total: -26.191045920046612 | Acciones/episodio:  1000 | Segundos/episodio:  4.834791898727417
# Episodio: 223 | Recompensa total: -34.24516852009143 | Acciones/episodio:  1000 | Segundos/episodio:  5.5483009815216064
# Episodio: 224 | Recompensa total: -103.73619136588968 | Acciones/episodio:  370 | Segundos/episodio:  1.3995246887207031
# Episodio: 225 | Recompensa total: -91.23605469634705 | Acciones/episodio:  144 | Segundos/episodio:  0.446213960647583
# Episodio: 226 | Recompensa total: -26.815413633227088 | Acciones/episodio:  1000 | Segundos/episodio:  4.214986085891724
# Episodio: 227 | Recompensa total: -34.77400025381328 | Acciones/episodio:  1000 | Segundos/episodio:  5.215932130813599
# Episodio: 228 | Recompensa total: -34.923359433459666 | Acciones/episodio:  1000 | Segundos/episodio:  4.058295011520386
# Episodio: 229 | Recompensa total: -108.61627628530715 | Acciones/episodio:  344 | Segundos/episodio:  1.5653958320617676
# Episodio: 230 | Recompensa total: 164.7972392648948 | Acciones/episodio:  730 | Segundos/episodio:  3.724436044692993
# Episodio: 231 | Recompensa total: -28.583966168083585 | Acciones/episodio:  1000 | Segundos/episodio:  5.145768880844116
# Episodio: 232 | Recompensa total: -24.394923480962976 | Acciones/episodio:  1000 | Segundos/episodio:  4.611075162887573
# Episodio: 233 | Recompensa total: -63.77387198394949 | Acciones/episodio:  1000 | Segundos/episodio:  4.398715019226074
# Episodio: 234 | Recompensa total: -168.9526229624272 | Acciones/episodio:  359 | Segundos/episodio:  1.2264351844787598
# Episodio: 235 | Recompensa total: -25.271197259873276 | Acciones/episodio:  1000 | Segundos/episodio:  4.027693033218384
# Episodio: 236 | Recompensa total: -57.65319274862133 | Acciones/episodio:  1000 | Segundos/episodio:  4.006303787231445
# Episodio: 237 | Recompensa total: -9.205700561152053 | Acciones/episodio:  1000 | Segundos/episodio:  4.136703968048096
# Episodio: 238 | Recompensa total: -38.85997261750435 | Acciones/episodio:  1000 | Segundos/episodio:  4.319460868835449
# Episodio: 239 | Recompensa total: -35.036112321445195 | Acciones/episodio:  1000 | Segundos/episodio:  4.920897006988525
# Episodio: 240 | Recompensa total: -75.51183075916384 | Acciones/episodio:  1000 | Segundos/episodio:  3.993577003479004
# Episodio: 241 | Recompensa total: -21.26794191561144 | Acciones/episodio:  1000 | Segundos/episodio:  4.367735862731934
# Episodio: 242 | Recompensa total: -62.99658611919838 | Acciones/episodio:  1000 | Segundos/episodio:  4.401292085647583
# Episodio: 243 | Recompensa total: -110.69752042762138 | Acciones/episodio:  1000 | Segundos/episodio:  3.769418954849243
# Episodio: 244 | Recompensa total: -32.4865398694663 | Acciones/episodio:  1000 | Segundos/episodio:  5.890833139419556
# Episodio: 245 | Recompensa total: -94.24000632713081 | Acciones/episodio:  62 | Segundos/episodio:  0.19175076484680176
# Episodio: 246 | Recompensa total: -26.362834404260685 | Acciones/episodio:  1000 | Segundos/episodio:  3.9525492191314697
# Episodio: 247 | Recompensa total: 24.590623007802606 | Acciones/episodio:  73 | Segundos/episodio:  0.2267131805419922
# Episodio: 248 | Recompensa total: -54.35524262709485 | Acciones/episodio:  85 | Segundos/episodio:  0.2522256374359131
# Episodio: 249 | Recompensa total: -4.141215086891847 | Acciones/episodio:  1000 | Segundos/episodio:  4.266037940979004
# Episodio: 250 | Recompensa total: -65.5812414419162 | Acciones/episodio:  925 | Segundos/episodio:  3.4815118312835693
# Episodio: 251 | Recompensa total: -93.01442356072496 | Acciones/episodio:  917 | Segundos/episodio:  3.895927906036377
# Episodio: 252 | Recompensa total: -182.88303505048628 | Acciones/episodio:  128 | Segundos/episodio:  0.4213540554046631
# Episodio: 253 | Recompensa total: -134.29850333231866 | Acciones/episodio:  1000 | Segundos/episodio:  3.692760944366455
# Episodio: 254 | Recompensa total: -52.072247750865095 | Acciones/episodio:  1000 | Segundos/episodio:  3.7979660034179688
# Episodio: 255 | Recompensa total: -56.6899541926138 | Acciones/episodio:  56 | Segundos/episodio:  0.1712021827697754
# Episodio: 256 | Recompensa total: -132.34286448307455 | Acciones/episodio:  204 | Segundos/episodio:  0.6448709964752197
# Episodio: 257 | Recompensa total: -46.16028597483401 | Acciones/episodio:  1000 | Segundos/episodio:  3.6405038833618164
# Episodio: 258 | Recompensa total: -26.702257194636296 | Acciones/episodio:  1000 | Segundos/episodio:  4.562939882278442
# Episodio: 259 | Recompensa total: -23.63102778535461 | Acciones/episodio:  1000 | Segundos/episodio:  3.9902000427246094
# Episodio: 260 | Recompensa total: -13.77928893847323 | Acciones/episodio:  1000 | Segundos/episodio:  3.5358917713165283
# Episodio: 261 | Recompensa total: -191.09877234752867 | Acciones/episodio:  112 | Segundos/episodio:  0.32809996604919434
# Episodio: 262 | Recompensa total: 7.490889782269662 | Acciones/episodio:  113 | Segundos/episodio:  0.3361542224884033
# Episodio: 263 | Recompensa total: -134.2552744784671 | Acciones/episodio:  110 | Segundos/episodio:  0.33137011528015137
# Episodio: 264 | Recompensa total: -13.393596655298825 | Acciones/episodio:  1000 | Segundos/episodio:  4.33988094329834
# Episodio: 265 | Recompensa total: -109.79814859047583 | Acciones/episodio:  108 | Segundos/episodio:  0.3326740264892578
# Episodio: 266 | Recompensa total: -62.0535277798417 | Acciones/episodio:  1000 | Segundos/episodio:  4.083924055099487
# Episodio: 267 | Recompensa total: -103.16631216319041 | Acciones/episodio:  434 | Segundos/episodio:  1.6221258640289307
# Episodio: 268 | Recompensa total: -43.53460775513095 | Acciones/episodio:  395 | Segundos/episodio:  1.3768298625946045
# Episodio: 269 | Recompensa total: -18.47276303521687 | Acciones/episodio:  1000 | Segundos/episodio:  3.7214560508728027
# Episodio: 270 | Recompensa total: -61.367548717401085 | Acciones/episodio:  1000 | Segundos/episodio:  3.591393232345581
# Episodio: 271 | Recompensa total: -179.90596772070506 | Acciones/episodio:  703 | Segundos/episodio:  2.8512747287750244
# Episodio: 272 | Recompensa total: -31.784500298330073 | Acciones/episodio:  1000 | Segundos/episodio:  4.971376895904541
# Episodio: 273 | Recompensa total: 230.8996228569693 | Acciones/episodio:  541 | Segundos/episodio:  1.8780832290649414
# Episodio: 274 | Recompensa total: -1.971328952494326 | Acciones/episodio:  1000 | Segundos/episodio:  4.605204820632935
# Episodio: 275 | Recompensa total: -23.372335887904924 | Acciones/episodio:  1000 | Segundos/episodio:  4.579997777938843
# Episodio: 276 | Recompensa total: -23.623535407004113 | Acciones/episodio:  1000 | Segundos/episodio:  4.468248128890991
# Episodio: 277 | Recompensa total: -91.81791837525084 | Acciones/episodio:  1000 | Segundos/episodio:  3.807400941848755
# Episodio: 278 | Recompensa total: -30.531662217857857 | Acciones/episodio:  1000 | Segundos/episodio:  4.145323753356934
# Episodio: 279 | Recompensa total: 15.943047047570584 | Acciones/episodio:  1000 | Segundos/episodio:  4.594146966934204
# Episodio: 280 | Recompensa total: -175.99944044248383 | Acciones/episodio:  303 | Segundos/episodio:  1.0435690879821777
# Episodio: 281 | Recompensa total: -6.9408720040205045 | Acciones/episodio:  1000 | Segundos/episodio:  3.8322832584381104
# Episodio: 282 | Recompensa total: -0.42114887517053656 | Acciones/episodio:  1000 | Segundos/episodio:  3.9889638423919678
# Episodio: 283 | Recompensa total: -84.84516171368556 | Acciones/episodio:  1000 | Segundos/episodio:  4.377037048339844
# Episodio: 284 | Recompensa total: 12.41070515076371 | Acciones/episodio:  1000 | Segundos/episodio:  3.513906240463257
# Episodio: 285 | Recompensa total: -85.87791138592394 | Acciones/episodio:  84 | Segundos/episodio:  0.3261988162994385
# Episodio: 286 | Recompensa total: -10.386349360835531 | Acciones/episodio:  1000 | Segundos/episodio:  3.9373810291290283
# Episodio: 287 | Recompensa total: -18.393474499573504 | Acciones/episodio:  1000 | Segundos/episodio:  3.986999034881592
# Episodio: 288 | Recompensa total: -123.25598842742025 | Acciones/episodio:  189 | Segundos/episodio:  0.6262128353118896
# Episodio: 289 | Recompensa total: -18.101343817967557 | Acciones/episodio:  1000 | Segundos/episodio:  4.133498191833496
# Episodio: 290 | Recompensa total: -31.55886353899058 | Acciones/episodio:  1000 | Segundos/episodio:  6.33189582824707
# Episodio: 291 | Recompensa total: 6.319003602445402 | Acciones/episodio:  1000 | Segundos/episodio:  4.586388826370239
# Episodio: 292 | Recompensa total: -63.82884690442974 | Acciones/episodio:  1000 | Segundos/episodio:  5.387737989425659
# Episodio: 293 | Recompensa total: -106.17325254233086 | Acciones/episodio:  93 | Segundos/episodio:  0.31418895721435547
# Episodio: 294 | Recompensa total: -93.69613804182814 | Acciones/episodio:  57 | Segundos/episodio:  0.18373918533325195
# Episodio: 295 | Recompensa total: 0.9851576754700346 | Acciones/episodio:  183 | Segundos/episodio:  0.7855970859527588
# Episodio: 296 | Recompensa total: -114.60655902166658 | Acciones/episodio:  53 | Segundos/episodio:  0.17752599716186523
# Episodio: 297 | Recompensa total: -64.58968755220283 | Acciones/episodio:  1000 | Segundos/episodio:  4.365291118621826
# Episodio: 298 | Recompensa total: -6.091864374480008 | Acciones/episodio:  1000 | Segundos/episodio:  5.303139686584473
# Episodio: 299 | Recompensa total: 15.216460818644695 | Acciones/episodio:  1000 | Segundos/episodio:  4.333805799484253
# Episodio: 300 | Recompensa total: -18.484625823760446 | Acciones/episodio:  1000 | Segundos/episodio:  4.187697887420654
# Episodio: 301 | Recompensa total: -35.55226458157119 | Acciones/episodio:  1000 | Segundos/episodio:  4.4033589363098145
# Episodio: 302 | Recompensa total: -38.2843522533518 | Acciones/episodio:  1000 | Segundos/episodio:  3.958936929702759
# Episodio: 303 | Recompensa total: 9.906134029915574 | Acciones/episodio:  1000 | Segundos/episodio:  4.833445072174072
# Episodio: 304 | Recompensa total: -149.74418080128555 | Acciones/episodio:  78 | Segundos/episodio:  0.2370619773864746
# Episodio: 305 | Recompensa total: -46.38430323657031 | Acciones/episodio:  1000 | Segundos/episodio:  3.928960084915161
# Episodio: 306 | Recompensa total: -35.85342192006382 | Acciones/episodio:  70 | Segundos/episodio:  0.21736812591552734
# Episodio: 307 | Recompensa total: -33.87098630759358 | Acciones/episodio:  232 | Segundos/episodio:  0.6894211769104004
# Episodio: 308 | Recompensa total: -41.52600572513494 | Acciones/episodio:  80 | Segundos/episodio:  0.2353801727294922
# Episodio: 309 | Recompensa total: -97.5833882785332 | Acciones/episodio:  137 | Segundos/episodio:  0.5458848476409912
# Episodio: 310 | Recompensa total: -1.0057961246957308 | Acciones/episodio:  1000 | Segundos/episodio:  5.174309968948364
# Episodio: 311 | Recompensa total: -29.501896725155277 | Acciones/episodio:  90 | Segundos/episodio:  0.2843010425567627
# Episodio: 312 | Recompensa total: -16.992038512439464 | Acciones/episodio:  95 | Segundos/episodio:  0.3370239734649658
# Episodio: 313 | Recompensa total: -56.51087306891121 | Acciones/episodio:  92 | Segundos/episodio:  0.3045980930328369
# Episodio: 314 | Recompensa total: -77.56857078518709 | Acciones/episodio:  156 | Segundos/episodio:  0.4913480281829834
# Episodio: 315 | Recompensa total: -32.666246385957386 | Acciones/episodio:  1000 | Segundos/episodio:  3.976578950881958
# Episodio: 316 | Recompensa total: -19.435582647195684 | Acciones/episodio:  1000 | Segundos/episodio:  3.6795740127563477
# Episodio: 317 | Recompensa total: -297.14086243319366 | Acciones/episodio:  206 | Segundos/episodio:  0.6294898986816406
# Episodio: 318 | Recompensa total: -9.571704934083092 | Acciones/episodio:  1000 | Segundos/episodio:  4.596436977386475
# Episodio: 319 | Recompensa total: -24.48552789925698 | Acciones/episodio:  168 | Segundos/episodio:  0.5052821636199951
# Episodio: 320 | Recompensa total: -56.36016455450345 | Acciones/episodio:  110 | Segundos/episodio:  0.33349084854125977
# Episodio: 321 | Recompensa total: 23.633759171244904 | Acciones/episodio:  1000 | Segundos/episodio:  4.169440031051636
# Episodio: 322 | Recompensa total: -58.39678390042939 | Acciones/episodio:  484 | Segundos/episodio:  1.6550920009613037
# Episodio: 323 | Recompensa total: -100.88024645430986 | Acciones/episodio:  89 | Segundos/episodio:  0.2682840824127197
# Episodio: 324 | Recompensa total: -26.231192047200437 | Acciones/episodio:  1000 | Segundos/episodio:  4.044704914093018
# Episodio: 325 | Recompensa total: -2.8190682561923097 | Acciones/episodio:  1000 | Segundos/episodio:  5.062438011169434
# Episodio: 326 | Recompensa total: 9.53868655767316 | Acciones/episodio:  1000 | Segundos/episodio:  5.221714019775391
# Episodio: 327 | Recompensa total: -22.932618753364554 | Acciones/episodio:  1000 | Segundos/episodio:  5.203172206878662
# Episodio: 328 | Recompensa total: -36.60848957751216 | Acciones/episodio:  280 | Segundos/episodio:  0.8953478336334229
# Episodio: 329 | Recompensa total: -79.50473291292167 | Acciones/episodio:  87 | Segundos/episodio:  0.2614450454711914
# Episodio: 330 | Recompensa total: -1.5893292494026208 | Acciones/episodio:  1000 | Segundos/episodio:  4.476846218109131
# Episodio: 331 | Recompensa total: -85.00582154357532 | Acciones/episodio:  60 | Segundos/episodio:  0.16903305053710938
# Episodio: 332 | Recompensa total: 18.161231391754317 | Acciones/episodio:  1000 | Segundos/episodio:  4.4260499477386475
# Episodio: 333 | Recompensa total: -35.74657304633732 | Acciones/episodio:  661 | Segundos/episodio:  2.5289111137390137
# Episodio: 334 | Recompensa total: 9.004005275516699 | Acciones/episodio:  1000 | Segundos/episodio:  4.077680826187134
# Episodio: 335 | Recompensa total: 14.08415546367479 | Acciones/episodio:  1000 | Segundos/episodio:  5.239328145980835
# Episodio: 336 | Recompensa total: -480.40651054365674 | Acciones/episodio:  101 | Segundos/episodio:  0.304502010345459
# Episodio: 337 | Recompensa total: -34.24533055855248 | Acciones/episodio:  268 | Segundos/episodio:  0.8478729724884033
# Episodio: 338 | Recompensa total: 2.471179258685164 | Acciones/episodio:  1000 | Segundos/episodio:  5.342417001724243
# Episodio: 339 | Recompensa total: -20.96210286348425 | Acciones/episodio:  1000 | Segundos/episodio:  4.015980005264282
# Episodio: 340 | Recompensa total: -89.4610728299813 | Acciones/episodio:  86 | Segundos/episodio:  0.26549220085144043
# Episodio: 341 | Recompensa total: -51.734522335110555 | Acciones/episodio:  1000 | Segundos/episodio:  4.681735992431641
# Episodio: 342 | Recompensa total: -15.537320019475215 | Acciones/episodio:  1000 | Segundos/episodio:  5.0096471309661865
# Episodio: 343 | Recompensa total: 1.5042092513955871 | Acciones/episodio:  1000 | Segundos/episodio:  5.2692742347717285
# Episodio: 344 | Recompensa total: -80.91835149054089 | Acciones/episodio:  73 | Segundos/episodio:  0.2291278839111328
# Episodio: 345 | Recompensa total: -95.58390419168742 | Acciones/episodio:  992 | Segundos/episodio:  3.538115978240967
# Episodio: 346 | Recompensa total: -26.948868848618147 | Acciones/episodio:  134 | Segundos/episodio:  0.45430803298950195
# Episodio: 347 | Recompensa total: -96.81523191904299 | Acciones/episodio:  61 | Segundos/episodio:  0.18741893768310547
# Episodio: 348 | Recompensa total: 211.52754581278083 | Acciones/episodio:  222 | Segundos/episodio:  0.7158210277557373
# Episodio: 349 | Recompensa total: -138.1294332095454 | Acciones/episodio:  73 | Segundos/episodio:  0.2207660675048828
# Episodio: 350 | Recompensa total: -38.56654328346761 | Acciones/episodio:  1000 | Segundos/episodio:  4.596024036407471
# Episodio: 351 | Recompensa total: -39.63740236871177 | Acciones/episodio:  1000 | Segundos/episodio:  5.247185945510864
# Episodio: 352 | Recompensa total: 0.05735007089861327 | Acciones/episodio:  1000 | Segundos/episodio:  4.116854906082153
# Episodio: 353 | Recompensa total: -15.080603596790812 | Acciones/episodio:  1000 | Segundos/episodio:  4.683077096939087
# Episodio: 354 | Recompensa total: 19.395927624705745 | Acciones/episodio:  1000 | Segundos/episodio:  4.029522180557251
# Episodio: 355 | Recompensa total: -109.68075344716947 | Acciones/episodio:  68 | Segundos/episodio:  0.20636892318725586
# Episodio: 356 | Recompensa total: 29.924511583871634 | Acciones/episodio:  1000 | Segundos/episodio:  4.1807169914245605
# Episodio: 357 | Recompensa total: -64.27419332672343 | Acciones/episodio:  65 | Segundos/episodio:  0.19769501686096191
# Episodio: 358 | Recompensa total: -43.08114521592123 | Acciones/episodio:  78 | Segundos/episodio:  0.2577552795410156
# Episodio: 359 | Recompensa total: -10.025484060619362 | Acciones/episodio:  81 | Segundos/episodio:  0.2948877811431885
# Episodio: 360 | Recompensa total: 3.2120081876685225 | Acciones/episodio:  1000 | Segundos/episodio:  5.2775959968566895
# Episodio: 361 | Recompensa total: 21.239846297639456 | Acciones/episodio:  1000 | Segundos/episodio:  4.936888933181763
# Episodio: 362 | Recompensa total: 45.566267588676595 | Acciones/episodio:  98 | Segundos/episodio:  0.31635308265686035
# Episodio: 363 | Recompensa total: 14.866643103814711 | Acciones/episodio:  1000 | Segundos/episodio:  4.329319953918457
# Episodio: 364 | Recompensa total: 5.220803729336112 | Acciones/episodio:  166 | Segundos/episodio:  0.5037341117858887
# Episodio: 365 | Recompensa total: -39.817749680576554 | Acciones/episodio:  81 | Segundos/episodio:  0.2441260814666748
# Episodio: 366 | Recompensa total: 4.0718692901354245 | Acciones/episodio:  108 | Segundos/episodio:  0.3296940326690674
# Episodio: 367 | Recompensa total: 32.62983039148299 | Acciones/episodio:  1000 | Segundos/episodio:  4.051192045211792
# Episodio: 368 | Recompensa total: -30.93973062907603 | Acciones/episodio:  1000 | Segundos/episodio:  4.9194159507751465
# Episodio: 369 | Recompensa total: -33.020718804640026 | Acciones/episodio:  75 | Segundos/episodio:  0.23072481155395508
# Episodio: 370 | Recompensa total: 1.3271451274668515 | Acciones/episodio:  1000 | Segundos/episodio:  4.3716161251068115
# Episodio: 371 | Recompensa total: 1.1170138760507977 | Acciones/episodio:  1000 | Segundos/episodio:  4.302862882614136
# Episodio: 372 | Recompensa total: 142.4405659754879 | Acciones/episodio:  650 | Segundos/episodio:  2.546689033508301
# Episodio: 373 | Recompensa total: -16.657125105780647 | Acciones/episodio:  1000 | Segundos/episodio:  5.453704118728638
# Episodio: 374 | Recompensa total: -87.7032956397857 | Acciones/episodio:  57 | Segundos/episodio:  0.1717970371246338
# Episodio: 375 | Recompensa total: 31.422064944034584 | Acciones/episodio:  1000 | Segundos/episodio:  4.818615913391113
# Episodio: 376 | Recompensa total: -33.92861718425973 | Acciones/episodio:  1000 | Segundos/episodio:  4.4314820766448975
# Episodio: 377 | Recompensa total: 10.019505409165363 | Acciones/episodio:  1000 | Segundos/episodio:  4.868674039840698
# Episodio: 378 | Recompensa total: -38.61378470110587 | Acciones/episodio:  57 | Segundos/episodio:  0.1759319305419922
# Episodio: 379 | Recompensa total: -40.20136228737255 | Acciones/episodio:  201 | Segundos/episodio:  0.6232831478118896
# Episodio: 380 | Recompensa total: -160.50467855045304 | Acciones/episodio:  132 | Segundos/episodio:  0.4056062698364258
# Episodio: 381 | Recompensa total: -50.58436835888719 | Acciones/episodio:  57 | Segundos/episodio:  0.16822600364685059
# Episodio: 382 | Recompensa total: -2.424030478988131 | Acciones/episodio:  1000 | Segundos/episodio:  4.868269920349121
# Episodio: 383 | Recompensa total: -44.88732249246053 | Acciones/episodio:  62 | Segundos/episodio:  0.19721388816833496
# Episodio: 384 | Recompensa total: -16.60911979516181 | Acciones/episodio:  1000 | Segundos/episodio:  4.043040037155151
# Episodio: 385 | Recompensa total: -31.994918101461778 | Acciones/episodio:  85 | Segundos/episodio:  0.2652559280395508
# Episodio: 386 | Recompensa total: -7.067963590297755 | Acciones/episodio:  1000 | Segundos/episodio:  4.020336151123047
# Episodio: 387 | Recompensa total: 0.11810245128917929 | Acciones/episodio:  1000 | Segundos/episodio:  3.9307870864868164
# Episodio: 388 | Recompensa total: -154.22367582780373 | Acciones/episodio:  122 | Segundos/episodio:  0.369002103805542
# Episodio: 389 | Recompensa total: 0.07127141047635838 | Acciones/episodio:  1000 | Segundos/episodio:  4.502594232559204
# Episodio: 390 | Recompensa total: -48.38616472054249 | Acciones/episodio:  79 | Segundos/episodio:  0.226578950881958
# Episodio: 391 | Recompensa total: -34.339244876641665 | Acciones/episodio:  1000 | Segundos/episodio:  4.804127931594849
# Episodio: 392 | Recompensa total: -94.33523620776005 | Acciones/episodio:  147 | Segundos/episodio:  0.4510517120361328
# Episodio: 393 | Recompensa total: -7.0313938373931535 | Acciones/episodio:  1000 | Segundos/episodio:  4.48984694480896
# Episodio: 394 | Recompensa total: 28.40985799479986 | Acciones/episodio:  1000 | Segundos/episodio:  4.2485058307647705
# Episodio: 395 | Recompensa total: -74.50048273003011 | Acciones/episodio:  58 | Segundos/episodio:  0.1658492088317871
# Episodio: 396 | Recompensa total: -0.22680553427381067 | Acciones/episodio:  1000 | Segundos/episodio:  4.400048732757568
# Episodio: 397 | Recompensa total: -38.60884583318661 | Acciones/episodio:  66 | Segundos/episodio:  0.19800806045532227
# Episodio: 398 | Recompensa total: -51.28303382148769 | Acciones/episodio:  87 | Segundos/episodio:  0.26781392097473145
# Episodio: 399 | Recompensa total: -26.13896044250471 | Acciones/episodio:  1000 | Segundos/episodio:  4.367953300476074
# ...
# Episodio: 867 | Recompensa total: 247.87982046288639 | Acciones/episodio:  569 | Segundos/episodio:  2.3584301471710205
# Episodio: 868 | Recompensa total: 251.72165380333374 | Acciones/episodio:  186 | Segundos/episodio:  0.6492841243743896
# Episodio: 869 | Recompensa total: 248.5578385506189 | Acciones/episodio:  195 | Segundos/episodio:  0.6677789688110352
# Episodio: 870 | Recompensa total: 245.32105048532003 | Acciones/episodio:  198 | Segundos/episodio:  0.71014404296875
# Episodio: 871 | Recompensa total: 271.24565065491515 | Acciones/episodio:  346 | Segundos/episodio:  1.2873890399932861
# Episodio: 872 | Recompensa total: 293.3638039151153 | Acciones/episodio:  316 | Segundos/episodio:  1.0731329917907715
# Episodio: 873 | Recompensa total: 2.1858882457738957 | Acciones/episodio:  118 | Segundos/episodio:  0.41677403450012207
# Episodio: 874 | Recompensa total: 273.0133829042064 | Acciones/episodio:  415 | Segundos/episodio:  1.5562679767608643
# Episodio: 875 | Recompensa total: 47.92865615725162 | Acciones/episodio:  130 | Segundos/episodio:  0.4566318988800049
# Episodio: 876 | Recompensa total: -89.02618563054192 | Acciones/episodio:  345 | Segundos/episodio:  1.3084170818328857
# Episodio: 877 | Recompensa total: 257.01652411187473 | Acciones/episodio:  296 | Segundos/episodio:  1.227452278137207
# Episodio: 878 | Recompensa total: 254.9610141624977 | Acciones/episodio:  383 | Segundos/episodio:  1.3534719944000244
# Episodio: 879 | Recompensa total: 240.20585353382828 | Acciones/episodio:  189 | Segundos/episodio:  0.7585079669952393
# Episodio: 880 | Recompensa total: 246.44512578449903 | Acciones/episodio:  167 | Segundos/episodio:  0.6155960559844971
# Episodio: 881 | Recompensa total: 20.293883375489457 | Acciones/episodio:  90 | Segundos/episodio:  0.3613598346710205
# Episodio: 882 | Recompensa total: 247.9359427276244 | Acciones/episodio:  190 | Segundos/episodio:  0.658581018447876
# Episodio: 883 | Recompensa total: -142.65960837077748 | Acciones/episodio:  153 | Segundos/episodio:  0.5260889530181885
# Episodio: 884 | Recompensa total: -129.84892418595487 | Acciones/episodio:  281 | Segundos/episodio:  0.96809983253479
# Episodio: 885 | Recompensa total: 269.88741846031604 | Acciones/episodio:  353 | Segundos/episodio:  1.2149019241333008
# Episodio: 886 | Recompensa total: 57.03251306553315 | Acciones/episodio:  149 | Segundos/episodio:  0.5043680667877197
# Episodio: 887 | Recompensa total: -21.225488844342095 | Acciones/episodio:  116 | Segundos/episodio:  0.37285518646240234
# Episodio: 888 | Recompensa total: 282.35608169834313 | Acciones/episodio:  362 | Segundos/episodio:  1.2689239978790283
# Episodio: 889 | Recompensa total: 249.7213394829357 | Acciones/episodio:  439 | Segundos/episodio:  1.5618102550506592
# Episodio: 890 | Recompensa total: 273.4971944594936 | Acciones/episodio:  175 | Segundos/episodio:  0.5974829196929932
# Episodio: 891 | Recompensa total: 269.274299047233 | Acciones/episodio:  332 | Segundos/episodio:  1.164715051651001
# Episodio: 892 | Recompensa total: 3.2838961070307704 | Acciones/episodio:  140 | Segundos/episodio:  0.5689253807067871
# Episodio: 893 | Recompensa total: 256.130718844764 | Acciones/episodio:  245 | Segundos/episodio:  0.8282411098480225
# Episodio: 894 | Recompensa total: 267.7044788923188 | Acciones/episodio:  277 | Segundos/episodio:  0.9591166973114014
# Episodio: 895 | Recompensa total: 268.7374903828839 | Acciones/episodio:  235 | Segundos/episodio:  0.8934810161590576
# Episodio: 896 | Recompensa total: 13.26205096556815 | Acciones/episodio:  121 | Segundos/episodio:  0.39931488037109375
# Episodio: 897 | Recompensa total: -201.818672291144 | Acciones/episodio:  178 | Segundos/episodio:  0.6021530628204346
# Episodio: 898 | Recompensa total: 235.59511835685282 | Acciones/episodio:  469 | Segundos/episodio:  2.0275208950042725
# Episodio: 899 | Recompensa total: -16.703196195144216 | Acciones/episodio:  134 | Segundos/episodio:  0.48545193672180176
# Episodio: 900 | Recompensa total: 276.19821086680224 | Acciones/episodio:  180 | Segundos/episodio:  0.6585369110107422
# Episodio: 901 | Recompensa total: -284.4930650127575 | Acciones/episodio:  307 | Segundos/episodio:  1.198214054107666
# Episodio: 902 | Recompensa total: -296.24931476287037 | Acciones/episodio:  310 | Segundos/episodio:  1.2169809341430664
# Episodio: 903 | Recompensa total: 285.6126234606704 | Acciones/episodio:  158 | Segundos/episodio:  0.5930190086364746
# Episodio: 904 | Recompensa total: 281.8306349375026 | Acciones/episodio:  229 | Segundos/episodio:  0.7761659622192383
# Episodio: 905 | Recompensa total: 286.75280984205506 | Acciones/episodio:  233 | Segundos/episodio:  0.8369731903076172
# Episodio: 906 | Recompensa total: 259.1670515287687 | Acciones/episodio:  248 | Segundos/episodio:  0.8595550060272217
# Episodio: 907 | Recompensa total: 63.49025226664253 | Acciones/episodio:  116 | Segundos/episodio:  0.4348609447479248
# Episodio: 908 | Recompensa total: -253.47204704022045 | Acciones/episodio:  473 | Segundos/episodio:  1.7280919551849365
# Episodio: 909 | Recompensa total: -227.3626100357235 | Acciones/episodio:  398 | Segundos/episodio:  1.434629201889038
# Episodio: 910 | Recompensa total: -29.574215983640613 | Acciones/episodio:  144 | Segundos/episodio:  0.5133481025695801
# Episodio: 911 | Recompensa total: -224.46113934604202 | Acciones/episodio:  259 | Segundos/episodio:  0.880014181137085
# Episodio: 912 | Recompensa total: -259.54005221875457 | Acciones/episodio:  342 | Segundos/episodio:  1.1772899627685547
# Episodio: 913 | Recompensa total: 236.5344732922128 | Acciones/episodio:  395 | Segundos/episodio:  1.658216953277588
# Episodio: 914 | Recompensa total: 229.90872349382224 | Acciones/episodio:  381 | Segundos/episodio:  1.536165714263916
# Episodio: 915 | Recompensa total: 278.7316420006203 | Acciones/episodio:  449 | Segundos/episodio:  1.7415599822998047
# Episodio: 916 | Recompensa total: 4.0523669029031595 | Acciones/episodio:  108 | Segundos/episodio:  0.3873469829559326
# Episodio: 917 | Recompensa total: -381.75884860743815 | Acciones/episodio:  399 | Segundos/episodio:  1.4690001010894775
# Episodio: 918 | Recompensa total: 291.600284882968 | Acciones/episodio:  234 | Segundos/episodio:  0.7816779613494873
# Episodio: 919 | Recompensa total: 268.54243350506965 | Acciones/episodio:  193 | Segundos/episodio:  0.7149097919464111
# Episodio: 920 | Recompensa total: 271.96817796547515 | Acciones/episodio:  156 | Segundos/episodio:  0.5978491306304932
# Episodio: 921 | Recompensa total: -303.8993398686341 | Acciones/episodio:  246 | Segundos/episodio:  0.8238141536712646
# Episodio: 922 | Recompensa total: -274.5211928351482 | Acciones/episodio:  239 | Segundos/episodio:  0.8486251831054688
# Episodio: 923 | Recompensa total: 259.43680768032027 | Acciones/episodio:  256 | Segundos/episodio:  0.9723377227783203
# Episodio: 924 | Recompensa total: 242.70924681668583 | Acciones/episodio:  440 | Segundos/episodio:  1.7519562244415283
# Episodio: 925 | Recompensa total: 241.26535135370528 | Acciones/episodio:  194 | Segundos/episodio:  0.6296849250793457
# Episodio: 926 | Recompensa total: 310.2227492864989 | Acciones/episodio:  250 | Segundos/episodio:  0.9168832302093506
# Episodio: 927 | Recompensa total: -418.13735677945823 | Acciones/episodio:  314 | Segundos/episodio:  1.1050598621368408
# Episodio: 928 | Recompensa total: 251.32419436332398 | Acciones/episodio:  218 | Segundos/episodio:  0.8540651798248291
# Episodio: 929 | Recompensa total: -129.438517811341 | Acciones/episodio:  151 | Segundos/episodio:  0.4898083209991455
# Episodio: 930 | Recompensa total: 290.20710092562445 | Acciones/episodio:  554 | Segundos/episodio:  2.3678090572357178
# Episodio: 931 | Recompensa total: 259.5008769909873 | Acciones/episodio:  255 | Segundos/episodio:  0.936366081237793
# Episodio: 932 | Recompensa total: -258.142874856081 | Acciones/episodio:  288 | Segundos/episodio:  1.118873119354248
# Episodio: 933 | Recompensa total: -198.54259912706914 | Acciones/episodio:  476 | Segundos/episodio:  1.826889991760254
# Episodio: 934 | Recompensa total: -441.2094288528565 | Acciones/episodio:  98 | Segundos/episodio:  0.4321150779724121
# Episodio: 935 | Recompensa total: -267.6079990575183 | Acciones/episodio:  379 | Segundos/episodio:  1.4103760719299316
# Episodio: 936 | Recompensa total: -2.5185916510757664 | Acciones/episodio:  169 | Segundos/episodio:  0.6122210025787354
# Episodio: 937 | Recompensa total: 275.576565129982 | Acciones/episodio:  454 | Segundos/episodio:  1.7691600322723389
# Episodio: 938 | Recompensa total: 267.29408957542057 | Acciones/episodio:  308 | Segundos/episodio:  1.2866859436035156
# Episodio: 939 | Recompensa total: 269.51979885927 | Acciones/episodio:  227 | Segundos/episodio:  0.7948389053344727
# Episodio: 940 | Recompensa total: 271.523341653073 | Acciones/episodio:  288 | Segundos/episodio:  0.9933960437774658
# Episodio: 941 | Recompensa total: 243.33756417705467 | Acciones/episodio:  268 | Segundos/episodio:  0.8821969032287598
# Episodio: 942 | Recompensa total: 248.31459734021917 | Acciones/episodio:  159 | Segundos/episodio:  0.6511580944061279
# Episodio: 943 | Recompensa total: 276.83257359968115 | Acciones/episodio:  236 | Segundos/episodio:  1.0406980514526367
# Episodio: 944 | Recompensa total: -187.40904709434375 | Acciones/episodio:  331 | Segundos/episodio:  1.32173490524292
# Episodio: 945 | Recompensa total: 283.95319416174044 | Acciones/episodio:  247 | Segundos/episodio:  0.9093236923217773
# Episodio: 946 | Recompensa total: 186.84825697431364 | Acciones/episodio:  885 | Segundos/episodio:  3.7767539024353027
# Episodio: 947 | Recompensa total: -264.58717878400876 | Acciones/episodio:  315 | Segundos/episodio:  1.1346518993377686
# Episodio: 948 | Recompensa total: 206.30420239637218 | Acciones/episodio:  511 | Segundos/episodio:  2.0385239124298096
# Episodio: 949 | Recompensa total: -334.03178745972735 | Acciones/episodio:  231 | Segundos/episodio:  0.8457479476928711
# Episodio: 950 | Recompensa total: 253.89285504959858 | Acciones/episodio:  363 | Segundos/episodio:  1.2820956707000732
# Episodio: 951 | Recompensa total: -487.1494521661383 | Acciones/episodio:  514 | Segundos/episodio:  2.1861209869384766
# Episodio: 952 | Recompensa total: 293.1163343463569 | Acciones/episodio:  259 | Segundos/episodio:  0.944329023361206
# Episodio: 953 | Recompensa total: 253.30411410538778 | Acciones/episodio:  209 | Segundos/episodio:  0.9112319946289062
# Episodio: 954 | Recompensa total: 244.09217219581103 | Acciones/episodio:  207 | Segundos/episodio:  0.7358407974243164
# Episodio: 955 | Recompensa total: 268.41734751347565 | Acciones/episodio:  261 | Segundos/episodio:  0.8952996730804443
# Episodio: 956 | Recompensa total: 226.57744343572713 | Acciones/episodio:  376 | Segundos/episodio:  1.3363399505615234
# Episodio: 957 | Recompensa total: 250.26315865350728 | Acciones/episodio:  219 | Segundos/episodio:  0.7577559947967529
# Episodio: 958 | Recompensa total: 256.18709438661557 | Acciones/episodio:  161 | Segundos/episodio:  0.5642659664154053
# Episodio: 959 | Recompensa total: 21.726472677000118 | Acciones/episodio:  139 | Segundos/episodio:  0.4807860851287842
# Episodio: 960 | Recompensa total: -283.59192575611064 | Acciones/episodio:  436 | Segundos/episodio:  1.7594599723815918
# Episodio: 961 | Recompensa total: 288.1102327420284 | Acciones/episodio:  285 | Segundos/episodio:  0.9936211109161377
# Episodio: 962 | Recompensa total: 277.92762541900214 | Acciones/episodio:  322 | Segundos/episodio:  1.1688299179077148
# Episodio: 963 | Recompensa total: 278.69432160094584 | Acciones/episodio:  275 | Segundos/episodio:  1.0297110080718994
# Episodio: 964 | Recompensa total: -22.385176838940737 | Acciones/episodio:  68 | Segundos/episodio:  0.23421287536621094
# Episodio: 965 | Recompensa total: 41.16072266550009 | Acciones/episodio:  195 | Segundos/episodio:  0.681765079498291
# Episodio: 966 | Recompensa total: 244.9100929797281 | Acciones/episodio:  190 | Segundos/episodio:  0.8356499671936035
# Episodio: 967 | Recompensa total: 273.6030067435785 | Acciones/episodio:  225 | Segundos/episodio:  0.8187084197998047
# Episodio: 968 | Recompensa total: 218.68622978274118 | Acciones/episodio:  281 | Segundos/episodio:  1.175084114074707
# Episodio: 969 | Recompensa total: 271.49807102854584 | Acciones/episodio:  251 | Segundos/episodio:  0.9186723232269287
# Episodio: 970 | Recompensa total: 257.9110357145746 | Acciones/episodio:  346 | Segundos/episodio:  1.668060302734375
# Episodio: 971 | Recompensa total: 309.78252290238584 | Acciones/episodio:  231 | Segundos/episodio:  0.8698668479919434
# Episodio: 972 | Recompensa total: -263.20756958362426 | Acciones/episodio:  263 | Segundos/episodio:  0.9609041213989258
# Episodio: 973 | Recompensa total: 227.12704124851257 | Acciones/episodio:  279 | Segundos/episodio:  1.2474339008331299
# Episodio: 974 | Recompensa total: 242.44566825440953 | Acciones/episodio:  223 | Segundos/episodio:  1.34902024269104
# Episodio: 975 | Recompensa total: 307.03362580299074 | Acciones/episodio:  380 | Segundos/episodio:  1.4636340141296387
# Episodio: 976 | Recompensa total: 264.8149614580045 | Acciones/episodio:  254 | Segundos/episodio:  0.9648990631103516
# Episodio: 977 | Recompensa total: 260.6539951922899 | Acciones/episodio:  215 | Segundos/episodio:  0.717292070388794
# Episodio: 978 | Recompensa total: 294.23792412694957 | Acciones/episodio:  266 | Segundos/episodio:  0.891610860824585
# Episodio: 979 | Recompensa total: -283.61357495346283 | Acciones/episodio:  97 | Segundos/episodio:  0.32181596755981445
# Episodio: 980 | Recompensa total: 12.820177759217856 | Acciones/episodio:  143 | Segundos/episodio:  0.4987950325012207
# Episodio: 981 | Recompensa total: 260.64595949106183 | Acciones/episodio:  198 | Segundos/episodio:  0.6703531742095947
# Episodio: 982 | Recompensa total: 228.46986067334825 | Acciones/episodio:  695 | Segundos/episodio:  2.658555030822754
# Episodio: 983 | Recompensa total: 262.1233273976006 | Acciones/episodio:  183 | Segundos/episodio:  0.607367753982544
# Episodio: 984 | Recompensa total: 233.7670420361028 | Acciones/episodio:  304 | Segundos/episodio:  1.0502338409423828
# Episodio: 985 | Recompensa total: 235.95744614632724 | Acciones/episodio:  177 | Segundos/episodio:  0.5864179134368896
# Episodio: 986 | Recompensa total: -274.794600449037 | Acciones/episodio:  427 | Segundos/episodio:  1.618561029434204
# Episodio: 987 | Recompensa total: -368.0219964952569 | Acciones/episodio:  506 | Segundos/episodio:  1.9063701629638672
# Episodio: 988 | Recompensa total: 292.997161605267 | Acciones/episodio:  291 | Segundos/episodio:  1.0679810047149658
# Episodio: 989 | Recompensa total: 293.12156582928156 | Acciones/episodio:  205 | Segundos/episodio:  0.7413098812103271
# Episodio: 990 | Recompensa total: 241.8461604298136 | Acciones/episodio:  314 | Segundos/episodio:  1.1251342296600342
# Episodio: 991 | Recompensa total: 214.44736134402132 | Acciones/episodio:  281 | Segundos/episodio:  0.9995567798614502
# Episodio: 992 | Recompensa total: 225.6432235622736 | Acciones/episodio:  215 | Segundos/episodio:  0.7110328674316406
# Episodio: 993 | Recompensa total: -222.47345358021286 | Acciones/episodio:  276 | Segundos/episodio:  1.2569260597229004
# Episodio: 994 | Recompensa total: -21.947991305434595 | Acciones/episodio:  1000 | Segundos/episodio:  4.437394142150879
# Episodio: 995 | Recompensa total: 261.51712933257755 | Acciones/episodio:  200 | Segundos/episodio:  0.7262928485870361
# Episodio: 996 | Recompensa total: 232.3425757148149 | Acciones/episodio:  176 | Segundos/episodio:  0.6227741241455078
# Episodio: 997 | Recompensa total: 256.5940910071299 | Acciones/episodio:  319 | Segundos/episodio:  1.1528351306915283
# Episodio: 998 | Recompensa total: 33.31860645817818 | Acciones/episodio:  242 | Segundos/episodio:  0.9276552200317383
# Episodio: 999 | Recompensa total: 251.38825017110537 | Acciones/episodio:  236 | Segundos/episodio:  0.8298687934875488

# %%
def plot_development_performance():
    import matplotlib.pyplot as plt
    fig_size = (6,2.2)

    # Reward per epidode
    plt.figure(figsize=fig_size)
    plt.plot(range(1,1+len(reward_per_episode)), reward_per_episode)
    plt.title("Reward per episode")
    plt.grid()
    plt.show()

    # Total Reward acumulated
    total_reward_acum = [sum(reward_per_episode[:i+1]) for i in range(len(reward_per_episode))]
    plt.figure(figsize=fig_size)
    plt.plot(range(1,1+len(total_reward_acum)), total_reward_acum)
    plt.title("Total Reward acumulated")
    plt.grid()
    plt.show()

    # Average reward
    plt.figure(figsize=fig_size)
    average_reward = [i/(ix+1) for ix,i in enumerate(total_reward_acum)]
    plt.plot(range(1,1+len(average_reward)), average_reward)
    plt.title("Average reward")
    plt.grid()
    plt.show()

    # Epsylon evolution
    plt.figure(figsize=fig_size)
    plt.plot(range(1,1+len(epsilon_evolution)), epsilon_evolution)
    plt.title("Epsylon decay")
    plt.grid()
    plt.show()

    # Actions per episode
    plt.figure(figsize=fig_size)
    plt.plot(range(1,1+len(actions_per_episode)), actions_per_episode)
    plt.title("Actions per episode")
    plt.grid()
    plt.show()

    # Time per episode (secondes)
    plt.figure(figsize=fig_size)
    plt.plot(range(1,1+len(time_per_episode)), time_per_episode)
    plt.title("Time per episode (seconds)")
    plt.grid()
    plt.show()
plot_development_performance()

# %% [markdown]
# ## Otras pruebas realizadas (FAVOR NO EVALUAR DE AQUI HACIA ABAJO) esta parte no esta bien revisada y puede tener errores
# Aquí había intentado realizar el modelo con una red hecha con tensorflow, pero iba muuuy lento.

# %%
import gym
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from collections import deque
import random
from tqdm import tqdm
import time

# Configuración del entorno
env = gym.make('LunarLander-v2')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# Hiperparámetros
n_episodes = 50
batch_size = 64
memory_size = 10000
gamma = 0.99  # Factor de descuento
epsilon = 1.0  # Tasa de exploración
epsilon_min = 0.05
epsilon_decay = 0.996
learning_rate = 0.001

# Creación del modelo de red neuronal principal
model = Sequential()
model.add(Dense(256, input_dim=state_size, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(action_size, activation='linear'))
model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate))

# Creación del modelo de red neuronal objetivo
target_model = Sequential()
target_model.add(Dense(256, input_dim=state_size, activation='relu'))
target_model.add(Dense(256, activation='relu'))
target_model.add(Dense(256, activation='relu'))
target_model.add(Dense(action_size, activation='linear'))
target_model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate))

# Creación del replay buffer
memory = deque(maxlen=memory_size)

# Función de acción epsilon-greedy
def epsilon_greedy_action(state, epsilon):
    if np.random.rand() <= epsilon:
        return env.action_space.sample()
    else:
        return np.argmax(model.predict(state, verbose=False))

# Listas de evolución
reward_per_episode = []
total_reward_acum =[]
average_reward = []
epsilon_evolution = []
actions_per_episode = []
time_per_episode = []

# Entrenamiento del agente
for episode in range(n_episodes):
    state = env.reset()
    state = np.reshape(state, [1, state_size])
    total_reward = 0
    done = False
    act = 0
    start_time = time.time() 

    while not done:
        # if episode % 10==0:
        #     env.render()

        # Elegir acción
        act += 1
        action = epsilon_greedy_action(state, epsilon)
        
        # Realizar acción y obtener siguiente estado, recompensa y estado de finalización
        next_state, reward, done, _ = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])

        # Almacenar la transición en el replay buffer
        memory.append((state, action, reward, next_state, done))

        # Actualizar estado actual
        state = next_state
        total_reward += reward
                
        # Actualizar la red neuronal utilizando el replay buffer
        # if len(memory) > batch_size:
        #     batch = random.sample(memory, batch_size)
        #     for state, action, reward, next_state, done in batch:
        #         target = reward
        #         if not done:
        #             target = reward + gamma * np.amax(target_model.predict(next_state, verbose=False)[0])
        #         target_f = model.predict(state, verbose=False)
        #         target_f[0][action] = target
        #     model.fit(state, target_f, epochs=1, verbose=False)
        if len(memory) > batch_size:
            batch = random.sample(memory, batch_size)
            states = []
            targets = []
            for state, action, reward, next_state, done in batch:
                target = reward
                if not done:
                    target = reward + gamma * np.amax(target_model.predict(next_state, verbose=False)[0])
                target_f = model.predict(state, verbose=False)
                target_f[0][action] = target
                states.append(state[0])
                targets.append(target_f[0])
            model.fit(np.array(states), np.array(targets), epochs=1, verbose=False)

        # Actualizar tasa de exploración
        if epsilon > epsilon_min:
            epsilon *= epsilon_decay

    # Actualizar el modelo objetivo al final de cada episodio
    target_model.set_weights(model.get_weights())

    # Guardar registros de rendimiento del modelo 
    end_time = time.time()  # Obtener el tiempo de finalización
    execution_time = end_time - start_time 
    time_per_episode.append(execution_time)
    reward_per_episode.append(total_reward)
    actions_per_episode.append(act)
    epsilon_evolution.append(epsilon)
    print("Episodio:", episode, "| Recompensa total:", total_reward, "| Acciones/episodio: ", act, "| Segundos/episodio: ", execution_time)

env.close()
# Out:
# 2023-06-22 17:23:32.313006: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 17:23:36.700935: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Episodio: 0 | Recompensa total: -609.3153510644223 | Acciones/episodio:  149 | Segundos/episodio:  386.3140470981598
# Episodio: 1 | Recompensa total: -0.3728497923552867 | Acciones/episodio:  3 | Segundos/episodio:  13.584734916687012
# Episodio: 2 | Recompensa total: -390.14534706035397 | Acciones/episodio:  60 | Segundos/episodio:  276.66310000419617
# Episodio: 3 | Recompensa total: -18.945113551013335 | Acciones/episodio:  18 | Segundos/episodio:  82.13389229774475
# Episodio: 4 | Recompensa total: -12.43695486224722 | Acciones/episodio:  39 | Segundos/episodio:  179.86586594581604
# Episodio: 5 | Recompensa total: -1.2865645140942743 | Acciones/episodio:  19 | Segundos/episodio:  89.74706196784973
# Episodio: 6 | Recompensa total: 1.626599035821543 | Acciones/episodio:  13 | Segundos/episodio:  62.22338604927063
# Episodio: 7 | Recompensa total: -89.6369626440293 | Acciones/episodio:  38 | Segundos/episodio:  189.42044711112976
# Episodio: 8 | Recompensa total: -6.045658375243216 | Acciones/episodio:  38 | Segundos/episodio:  182.538094997406
# Episodio: 9 | Recompensa total: -35.46456072569977 | Acciones/episodio:  19 | Segundos/episodio:  99.29599404335022
# Episodio: 10 | Recompensa total: -96.93013242594512 | Acciones/episodio:  66 | Segundos/episodio:  318.95112800598145
# Episodio: 11 | Recompensa total: -274.98029473624536 | Acciones/episodio:  64 | Segundos/episodio:  319.21479392051697
# Episodio: 12 | Recompensa total: -2319.612233157505 | Acciones/episodio:  119 | Segundos/episodio:  630.3790278434753
# Episodio: 13 | Recompensa total: -7.549922913665631 | Acciones/episodio:  2 | Segundos/episodio:  10.17126989364624
# Episodio: 14 | Recompensa total: -202.11485519632762 | Acciones/episodio:  48 | Segundos/episodio:  234.19784927368164
# Episodio: 15 | Recompensa total: -1.7946217350812208 | Acciones/episodio:  1 | Segundos/episodio:  4.887784004211426
# Episodio: 16 | Recompensa total: -6.452304559803249 | Acciones/episodio:  3 | Segundos/episodio:  14.575271129608154
# Episodio: 17 | Recompensa total: -23.91233060692217 | Acciones/episodio:  15 | Segundos/episodio:  127.53453278541565
# Episodio: 18 | Recompensa total: -193.9707649529544 | Acciones/episodio:  54 | Segundos/episodio:  285.13813495635986
# Episodio: 19 | Recompensa total: -63.20831015581201 | Acciones/episodio:  25 | Segundos/episodio:  145.96035027503967
# Episodio: 20 | Recompensa total: -0.7960673825613402 | Acciones/episodio:  6 | Segundos/episodio:  34.777607917785645
# Episodio: 21 | Recompensa total: -44.767685787361685 | Acciones/episodio:  19 | Segundos/episodio:  106.88258576393127
# Episodio: 22 | Recompensa total: -1.7694574356099213 | Acciones/episodio:  1 | Segundos/episodio:  4.954757928848267
# Episodio: 23 | Recompensa total: 0.6567633299544888 | Acciones/episodio:  2 | Segundos/episodio:  10.351768732070923
# Episodio: 24 | Recompensa total: 3.2782019084852188 | Acciones/episodio:  3 | Segundos/episodio:  16.712893962860107
# Episodio: 25 | Recompensa total: -131.1975069097954 | Acciones/episodio:  34 | Segundos/episodio:  189.59490203857422
# Episodio: 26 | Recompensa total: -289.44650333889933 | Acciones/episodio:  59 | Segundos/episodio:  319.30289602279663
# Episodio: 27 | Recompensa total: -13.025978898094547 | Acciones/episodio:  68 | Segundos/episodio:  445.7342059612274
# Episodio: 28 | Recompensa total: -138.04270911856185 | Acciones/episodio:  36 | Segundos/episodio:  202.58766293525696
# Episodio: 29 | Recompensa total: -1.2309850862230491 | Acciones/episodio:  7 | Segundos/episodio:  39.66195511817932
# Episodio: 30 | Recompensa total: -136.90387342763609 | Acciones/episodio:  43 | Segundos/episodio:  239.8612940311432
# Episodio: 31 | Recompensa total: -155.7101886544915 | Acciones/episodio:  42 | Segundos/episodio:  230.37218189239502
# Episodio: 32 | Recompensa total: 4.3734604484137405 | Acciones/episodio:  16 | Segundos/episodio:  145.61958599090576
# Episodio: 33 | Recompensa total: -6647.195771999183 | Acciones/episodio:  125 | Segundos/episodio:  1319.3461089134216
# Episodio: 34 | Recompensa total: 0.6670207737633984 | Acciones/episodio:  1 | Segundos/episodio:  6.681854248046875
# Episodio: 35 | Recompensa total: -0.4250307345525346 | Acciones/episodio:  1 | Segundos/episodio:  7.694617986679077
# Episodio: 36 | Recompensa total: -10.558979555418569 | Acciones/episodio:  10 | Segundos/episodio:  60.12497878074646
# Episodio: 37 | Recompensa total: 8.415539954745704 | Acciones/episodio:  6 | Segundos/episodio:  36.24522399902344
# Episodio: 38 | Recompensa total: -4.223921807516606 | Acciones/episodio:  14 | Segundos/episodio:  127.70180106163025
# Episodio: 39 | Recompensa total: -10.549236663380366 | Acciones/episodio:  12 | Segundos/episodio:  61.45062875747681
# Episodio: 40 | Recompensa total: -23.31316524761106 | Acciones/episodio:  13 | Segundos/episodio:  67.71724700927734
# Episodio: 41 | Recompensa total: -1.7628262848332823 | Acciones/episodio:  29 | Segundos/episodio:  156.73712182044983
# Episodio: 42 | Recompensa total: -7.094171457940544 | Acciones/episodio:  9 | Segundos/episodio:  51.50773596763611
# Episodio: 43 | Recompensa total: -28.341132659667906 | Acciones/episodio:  16 | Segundos/episodio:  91.3798017501831
# Episodio: 44 | Recompensa total: -8.931795281383183 | Acciones/episodio:  11 | Segundos/episodio:  57.35874104499817
# Episodio: 45 | Recompensa total: -60.44450445830979 | Acciones/episodio:  32 | Segundos/episodio:  162.68038201332092
# Episodio: 46 | Recompensa total: -1.0658259557042744 | Acciones/episodio:  4 | Segundos/episodio:  19.468393087387085
# Episodio: 47 | Recompensa total: -14.608491840860824 | Acciones/episodio:  9 | Segundos/episodio:  45.609294176101685
# Episodio: 48 | Recompensa total: -171.93276987724315 | Acciones/episodio:  35 | Segundos/episodio:  210.75489902496338
# Episodio: 49 | Recompensa total: -3.563155947432456 | Acciones/episodio:  11 | Segundos/episodio:  60.3381621837616

# %%
plot_development_performance()
